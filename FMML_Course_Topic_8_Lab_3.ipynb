# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagasuma2004/FMML-_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 13:13:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   169MB/s    in 0.4s
#
# 2023-05-04 13:13:59 (169 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 34071  1604.08504v2  Spammer detection on social network is a chall...    cs
# 7741   1803.00841v1  In modern data analysis, random sampling is an...  stat
# 3738   1606.01855v1  We introduce Bayesian Poisson Tucker decomposi...  stat
# 9709   1710.01416v1  In the emerging advancement in the branch of a...    cs
# 23323   1106.2357v1  This papers introduces a new family of iris en...    cs
# ...             ...                                                ...   ...
# 12592  1803.03666v1  We propose a Standing Wave Decomposition (SWD)...  stat
# 14859   1104.2034v1  This article presents a fragment of a new comp...    cs
# 6230   1610.00494v3  We consider the problem of efficient "on the f...  stat
# 25260  1507.00019v2  In this paper, we study the problem of using c...    cs
# 40828   1405.6223v1  The essence of the challenges cold start and s...    cs
#
#                                                    title  year  \
# 34071  Detecting "Smart" Spammers On Social Network: ...  2016
# 7741   Gradient-based Sampling: An Adaptive Importanc...  2018
# 3738   Bayesian Poisson Tucker Decomposition for Lear...  2016
# 9709   Smoothness-based Edge Detection using Low-SNR ...  2017
# 23323  Comparing Haar-Hilbert and Log-Gabor Based Iri...  2011
# ...                                                  ...   ...
# 12592       Standing Wave Decomposition Gaussian Process  2018
# 14859  Materials to the Russian-Bulgarian Comparative...  2011
# 6230   One-Trial Correction of Legacy AI Systems and ...  2016
# 25260  Representing data by sparse combination of con...  2015
# 40828            Coupled Item-based Matrix Factorization  2014
#
#                                                 keywords
# 34071  [detection, challenging, emergence, legitimate...
# 7741   [efficient, computational, difficulties, resea...
# 3738   [introduce, decomposition, interaction, intera...
# 9709   [advancement, autonomous, efficiently, constru...
# 23323  [introduces, dimensional, transform, attenuati...
# ...                                                  ...
# 12592  [decomposition, approximation, regression, inv...
# 14859  [comparative, dictionary, comparative, diction...
# 6230   [efficient, artificial, intelligence, arbitrar...
# 25260  [contextual, classification, represent, recons...
# 40828  [challenges, recommender, techniques, collabor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 34071    [detection, challenging, emergence, legitimate...
# 7741     [efficient, computational, difficulties, resea...
# 3738     [introduce, decomposition, interaction, intera...
# 9709     [advancement, autonomous, efficiently, constru...
# 23323    [introduces, dimensional, transform, attenuati...
#                                ...
# 9933     [mathematical, libraries, inference, correspon...
# 6722     [abstention, feedbacks, abstention, important,...
# 13503    [significant, challenge, algorithmics, identif...
# 11955    [important, traditionally, quadratic, programm...
# 38649    [algorithm, geometrical, retrieval, geometrica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8809 words.
# Out of those 4601 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="129566fe-6053-4722-94e7-4434d97e0e35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("129566fe-6053-4722-94e7-4434d97e0e35")) {                    Plotly.newPlot(                        "129566fe-6053-4722-94e7-4434d97e0e35",                        [{"x":["detecting","detection","benchmark","classification","emergence","collected","outperforms","distribution","difficult","legitimate","information","dirichlet","challenging","researchers","synthetic","dependent","difficulties","theoretically","informative","conducted","efficiency","probabilities","according","computationally","importance","dimension","statistical","independent","computational","performance","advantage","empirically","establish","establishes","efficient","computing","demonstrate","community","structure","introduce","communities","knowledge","relations","international","memberships","including","interpretable","discovers","interaction","decomposition","inference","overlapping","predictive","algorithm","techniques","technique","conventional","navigation","environment","surrounding","navigational","effectively","advancement","surroundings","displayed","autonomous","comparisons","motivation","construct","methodology","utilizing","localization","smoothness","processed","efficiently","attenuation","classical","dimensional","introduces","presented","processing","comparing","involving","usefulness","comparable","recognition","transform","preventing","increases","organizations","wikileaks","sensitive","innovative","containing","available","cybersecurity","prevention","classified","ineffective","accessing","similarity","traditional","complexity","annotated","automated","paragraph","relationship","documents","granularity","constructed","confidential","paragraphs","organization","governments","artificially","interpretation","discusses","implementations","determination","combination","discussion","reference","reasoning","philosophical","contributes","evidential","presenting","statistic","simulation","generalized","numerical","procedures","procedure","theoretical","likelihood","characterize","projections","fundamental","sequential","projection","sketching","approximations","simulations","particular","leverages","dimensionality","compactness","objective","artifacts","reduction","estimation","optimization","experimental","sequentially","embedding","embeddings","extension","framework","additionally","probability","probabilistic","assessments","elicitation","observation","construction","treatment","experiences","influence","transcribing","predictor","prediction","approximate","computation","application","prohibitive","composite","parameters","scenarios","theoretic","recursive","processes","approximation","architecture","populations","nonlinear","improvement","individuals","supportive","infectious","interference","operative","polynomial","associated","regression","susceptible","interacting","mathematical","regarding","phenomenon","preprocessing"],"y":[72,360,210,504,17,72,283,201,147,3,707,18,280,74,133,79,25,53,37,92,161,56,91,91,83,55,153,130,268,858,90,71,56,8,407,133,597,70,350,323,26,364,89,8,1,247,24,5,68,69,189,18,59,830,374,277,108,33,135,17,3,148,6,7,8,51,30,12,94,81,55,58,25,21,159,4,94,182,80,186,271,90,59,25,93,384,74,8,60,10,1,68,12,44,308,1,3,30,5,4,140,179,220,65,109,4,76,76,8,74,1,5,20,2,6,50,23,48,19,149,28,62,128,7,11,8,23,7,66,58,79,37,110,149,71,51,20,88,82,59,2,34,45,283,33,55,8,181,25,100,187,343,380,17,105,74,86,565,57,184,151,10,4,53,67,27,14,65,2,16,231,119,149,245,7,16,245,90,45,20,103,130,234,11,57,136,33,3,2,14,2,59,93,115,9,15,63,46,23,24],"type":"bar"},{"x":["detecting","detection","benchmark","classification","emergence","collected","outperforms","distributio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4601,), (4601, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gray</span> <span style=''>Level</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.9459459459459459);'>Enhancement</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Polygonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6190476190476191);'>enhancing</span> <span style=''>the</span> <span style=''>gray</span> <span style=''>level</span> <span style=''>images</span> <span style=''>This</span> <span style=''>method</span> <span style=''>takes</span> <span style=''>part</span> <span style=''>from</span> <span style=''>the</span> <span style=''>category</span> <span style=''>of</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforms</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>The</span> <span style=''>latter</span> <span style=''>have</span> <span style=''>a</span> <span style=''>graphic</span> <span style='background-color:rgba(0, 255, 0, 0.3576642335766423);'>represented</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>polygonal</span> <span style=''>lines</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolation</span> <span style=''>nodes</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.36170212765957444);'>calculated</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37037037037037035);'>statistics</span> <span style=''>of</span> <span style=''>gray</span> <span style=''>levels</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>belonging</span> <span style=''>to</span> <span style=''>the</span> <span style=''>image</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Particle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>is</span> <span style=''>a</span> <span style=''>central</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>discrete</span> <span style=''>particle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>(DPVI)</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strengths</span> <span style=''>of</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>and</span> <span style=''>search</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>DPVI</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>family</span> <span style=''>of</span> <span style=''>particle</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>fit</span> <span style=''>using</span> <span style=''>simple</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Like</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>DPVI</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>multiple</span> <span style=''>modes</span> <span style=''>and</span> <span style=''>yields</span> <span style=''>exact</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>well</span> <span style=''>defined</span> <span style=''>limit</span> <span style=''>Like</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unstructured</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>DPVI</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>when</span> <span style=''>this</span> <span style=''>quantity</span> <span style=''>is</span> <span style=''>not</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>interest</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Seeding</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3829787234042554);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3626373626373627);'>maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5037593984962405);'>multivariate</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>Our</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>adaptions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>K</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Gonzalez</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Thereby</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>close</span> <span style=''>the</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>simple</span> <span style=''>random</span> <span style=''>eg</span> <span style=''>uniform</span> <span style=''>and</span> <span style=''>complex</span> <span style=''>methods</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>crucially</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>right</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hyperparameters</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>indicate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>usefulness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>methods</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>and</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>eg</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>original</span> <span style=''>K</span> <span style=''>means</span> <span style=''>and</span> <span style=''>Gonzalez</span> <span style=''>directly</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4619289340101522);'>artificial</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>sets</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Development</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>model</span> <span style=''>for</span> <span style=''>protein</span> <span style=''>ligand</span> <span style=''>binding</span> <span style=''>affinity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>based</span> <span style=''>ligand</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmenting</span> <span style=''>the</span> <span style=''>drug</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Currently</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>notable</span> <span style=''>shift</span> <span style=''>towards</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>(ML)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodologies</span> <span style=''>to</span> <span style=''>aid</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>Deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>gained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>as</span> <span style=''>it</span> <span style=''>allows</span> <span style=''>the</span> <span style=''>model</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>features</span> <span style=''>that</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>for</span> <span style=''>the</span> <span style=''>task</span> <span style=''>at</span> <span style=''>hand</span> <span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>binding</span> <span style=''>affinity</span> <span style=''>of</span> <span style=''>ligand</span> <span style=''>receptor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexes</span> <span style=''>The</span> <span style=''>complex</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>with</span> <span style=''>a</span> <span style=''>3D</span> <span style=''>grid</span> <span style=''>and</span> <span style=''>the</span> <span style=''>model</span> <span style=''>utilizes</span> <span style=''>a</span> <span style=''>3D</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolution</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>a</span> <span style=''>feature</span> <span style=''>map</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>treating</span> <span style=''>the</span> <span style=''>atoms</span> <span style=''>of</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.13041920458616982)
# 	experimental (0.1361519168756718)
# 	architecture (0.08384091723396632)
# 	segmentation (0.06915084199211752)
# 	information (0.25331422429236833)
# 	representation (0.1415263346470799)
# 	different (0.26549623790756)
# 	detection (0.12898602651379434)
# 	recognition (0.1375850949480473)
# 	convolutional (0.1429595127194554)
#
# Some Statistics words are:
# 	stochastic (0.12244897959183673)
# 	variables (0.13539074166251866)
# 	estimation (0.16177202588352413)
# 	algorithm (0.3957192633150821)
# 	theoretical (0.15480338476854155)
# 	statistical (0.15978098556495768)
# 	distribution (0.18168242906918866)
# 	dimensional (0.1911398705823793)
# 	inference (0.19412643106022898)
# 	regression (0.17869586859133899)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="056f6354-ff17-40a1-9775-c3c04df7a95f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("056f6354-ff17-40a1-9775-c3c04df7a95f")) {                    Plotly.newPlot(                        "056f6354-ff17-40a1-9775-c3c04df7a95f",                        [{"x":["detecting","detection","benchmark","classification","emergence","collected","outperforms","distribution","difficult","legitimate","information","dirichlet","challenging","researchers","synthetic","dependent","difficulties","theoretically","informative","conducted","efficiency","probabilities","according","computationally","importance","dimension","statistical","independent","computational","performance","advantage","empirically","establish","establishes","efficient","computing","demonstrate","community","structure","introduce","communities","knowledge","relations","international","memberships","including","interpretable","discovers","interaction","decomposition","inference","overlapping","predictive","algorithm","techniques","technique","conventional","navigation","environment","surrounding","navigational","effectively","advancement","surroundings","displayed","autonomous","comparisons","motivation","construct","methodology","utilizing","localization","smoothness","processed","efficiently","attenuation","classical","dimensional","introduces","presented","processing","comparing","involving","usefulness","comparable","recognition","transform","preventing","increases","organizations","wikileaks","sensitive","innovative","containing","available","cybersecurity","prevention","classified","ineffective","accessing","similarity","traditional","complexity","annotated","automated","paragraph","relationship","documents","granularity","constructed","confidential","paragraphs","organization","governments","artificially","interpretation","discusses","implementations","determination","combination","discussion","reference","reasoning","philosophical","contributes","evidential","presenting","statistic","simulation","generalized","numerical","procedures","procedure","theoretical","likelihood","characterize","projections","fundamental","sequential","projection","sketching","approximations","simulations","particular","leverages","dimensionality","compactness","objective","artifacts","reduction","estimation","optimization","experimental","sequentially","embedding","embeddings","extension","framework","additionally","probability","probabilistic","assessments","elicitation","observation","construction","treatment","experiences","influence","transcribing","predictor","prediction","approximate","computation","application","prohibitive","composite","parameters","scenarios","theoretic","recursive","processes","approximation","architecture","populations","nonlinear","improvement","individuals","supportive","infectious","interference","operative","polynomial","associated","regression","susceptible","interacting","mathematical","regarding","phenomenon","preprocessing","developed","realistic","dependence","linguistic","candidates","sentences","description","exercises","comprehensive","evaluation","addressed","heuristics","selection","empirical","combining","identification","educational","implementation","candidate","generation","extracted","integrated","providing","underlying","strategies","extensive","experiments","comparison","investigate","characteristics","behaviour","understanding","suppresses","orientation","extremely","attention","convolutional","automatically","detectors","substantially","producing","background","hierarchical","inception","identifies","essentially","mechanism","particularly","attentional","advancing","aggregates","furthermore","overfitting","baselines","supervision","subsequent","negative ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	katehakis
# 	tempering
# 	procrustes
# 	dichotomy
# 	correntropy
# 	favourably
# 	tibshirani
# 	smoothers
# 	transcriptional
# 	manifests
# 	permitted
# 	maximizer
# 	cancellation
# 	exposition
# 	astronomical
# 	parallelize
# 	convexification
# 	everything
# 	instantiate
# 	confounders
# Some words which never appear in Statistics papers:
# 	navigation
# 	navigational
# 	attenuation
# 	paragraph
# 	paragraphs
# 	evidential
# 	transcribing
# 	operative
# 	accommodated
# 	surprisal
# 	referents
# 	concatenation
# 	curriculum
# 	curricula
# 	bucketing
# 	orderings
# 	syntactic
# 	precursor
# 	formalisms
# 	connectives

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0758820091661287e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
